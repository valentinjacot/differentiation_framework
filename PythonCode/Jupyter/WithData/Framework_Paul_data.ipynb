# %%
# 1
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import scipy.sparse as ss
from scipy import stats
from fenics import *

# import scipy.linalg as sl


# from mpl_toolkits.mplot3d import Axes3D
# from mshr import *
# from ufl import nabla_grad, nabla_div, grad
# from scipy.interpolate import interp2d
# from abc import abstractmethod

# %matplotlib notebook

# %%
mat = scipy.io.loadmat('../../Matlab/Paul2015_scRNAseqData.mat')

# %%
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Sun Aug 11 22:05:03 2019',
#  '__version__': '1.0',
#  '__globals__': ['genename'],
#  'cluster': array([[6, 2, 8, ..., 6, 3, 4]], dtype=uint8),
#  'genename': array([[array(['0610007L01Rik'], dtype='<U13')],
#         [array(['0610009O20Rik'], dtype='<U13')],
#         [array(['0610010K14Rik'], dtype='<U13')],
#         ...,
#         [array(['mKIAA1994'], dtype='<U9')],
#         [array(['rp9'], dtype='<U3')],
#         [array(['slc43a2'], dtype='<U7')]], dtype=object),
#  'scdata': array([[0, 0, 1, ..., 0, 3, 0],
#         [0, 0, 0, ..., 0, 0, 0],
#         [0, 1, 3, ..., 1, 3, 4],
#         ...,
#         [0, 0, 2, ..., 0, 0, 1],
#         [2, 1, 3, ..., 0, 1, 1],
#         [0, 0, 0, ..., 0, 0, 1]], dtype=uint8)}

# %%
mat['scdata'].shape
# Out:
# (3451, 2730)

# %%
scdata= np.log2(mat['scdata']+ 1)

# %%
scdata.shape
# Out:
# (3451, 2730)

# %%
DMsig = 50 
N = np.array([100, 120])
no_dims = 20
alpha = 0.5

# %%
test_val = np.array([10, 15])
print(pow(test_val,2))
# Out:
# [100 225]

# %%
# DiffusionMap_wNewData.m
# [dc, dcSig] = DiffusionMap_wNewData( scdata', [], DMdim, alpha, DMsig );
# [mappedX, S, mappedY] = DiffusionMap_wNewData(X, Y, no_dims, alpha, sigma)
X = scdata.T
X = X - X.min()
X = X/X.max()
print(X.shape)
sumX = np.sum(pow(X,2),axis=1)
print(sumX.shape)
X = ss.csc_matrix(X)
# print(np.dot(X, X.T).shape)
# Out:
# (2730, 3451)
# (2730,)

# %%
K = np.exp(-(sumX+(sumX.T + (-2) * np.dot(X, X.T))) / (2*DMsig**2))
# K = exp(-bsxfun(@plus, sumX, bsxfun(@plus, sumX', -2 * (X * X'))) ./ (2 .* sigma ^ 2));
print(K.shape)
# Out:
# (2730, 2730)

# %%
# print(np.isinf(p*p.T).any())
print(K.shape)
# Out:
# (2730, 2730)

# %%
p  = np.sum(K,0).T
pp = p*p.T
# pp[np.isinf(pp)] = 10E3
# pp[np.isnan(pp)] = 0
K  = K / (np.sqrt(pp))
print(K)
# Out:
# [[0.00036638 0.00036152 0.00035764 ... 0.00036545 0.00036017 0.00035484]
#  [0.00036812 0.00036976 0.00036402 ... 0.00036808 0.00036662 0.00036228]
#  [0.00037115 0.000371   0.00037482 ... 0.00037115 0.00037093 0.00037085]
#  ...
#  [0.00036575 0.00036177 0.00035793 ... 0.00036649 0.00036046 0.00035519]
#  [0.00036914 0.00036901 0.00036632 ... 0.00036914 0.00037145 0.00036487]
#  [0.00037331 0.00037431 0.00037595 ... 0.00037338 0.00037454 0.00037864]]

# %%
p  = np.sqrt(np.sum(K,0)).T
K  = K / (p*p.T)     
print(K.shape)
# Out:
# (2730, 2730)

# %%
u, s, vh = np.linalg.svd(K, full_matrices=False)

# %%
s.shape
# Out:
# (2730,)

# %%
dc = u/u[:,0]
# print(dc)
print(dc.shape)
dc =  dc[:,1:no_dims+1]
print(dc.T.shape)
# S = np.diag(s)
S = s[1:no_dims+1]
print(S.shape)
print(dc.shape)
# Out:
# (2730, 2730)
# (20, 2730)
# (20,)
# (2730, 20)

# %%
# dc_normalize.m
minmax = np.zeros((no_dims,2))
print(minmax.shape)
data = np.zeros((2730,no_dims))
print(data.shape)
dL=0
for n in range(0,no_dims):
    minmax[n,0] = dc[:,n].min()
    minmax[n,1] = dc[:,n].max()
    dL = minmax[n,1] - minmax[n,0] 
    minmax[n,0] = minmax[n,0] - dL*0.15
    minmax[n,1] = minmax[n,1] + dL*0.15

print(dc.T[:,0:no_dims].shape)
print(data[:,0:no_dims].shape)
# for n in range(0,no_dims):
#     data[:,n] = dc.T[:,n] #-  minmax[n,0])/(minmax[n,1]-minmax[n,0])
data[:,0:no_dims] = (dc[:,0:no_dims] -  minmax[0:no_dims,0])/(minmax[0:no_dims,1]-minmax[0:no_dims,0])

# dc.assign(data)
print(data.shape)
# Out:
# (20, 2)
# (2730, 20)
# (20, 20)
# (2730, 20)
# (2730, 20)

# %%
print(minmax)
# Out:
# [[-2.36836065  4.7105893 ]
#  [-3.94535     2.03885396]
#  [-4.49566566  8.277202  ]
#  [-4.47265382  4.63774915]
#  [-5.02794684  4.34472622]
#  [-4.15015682  4.17075547]
#  [-5.36361686  4.55323569]
#  [-6.49964384  4.98165492]
#  [-5.93204839  6.77388961]
#  [-5.37737575  6.38027015]
#  [-6.71204212 10.62355402]
#  [-4.54797559  4.22419648]
#  [-4.56746694  5.1067886 ]
#  [-9.70600851  6.96595008]
#  [-4.59601706  5.23468775]
#  [-5.98253114  7.40994556]
#  [-6.74889044 17.18551186]
#  [-5.07396063  5.84328564]
#  [-6.11385112  7.03281074]
#  [-4.9099704   4.69786131]]

# %%
print(dL)
print(dc.shape)
# Out:
# 7.390639781951904
# (2730, 20)

# %%
np.isnan(data.T).any()
# Out:
# False

# %%
# compute_homeostasis 
x = np.arange(0, 1.0, 1 / 100).T
y = np.arange(0, 1.0, 1 / 100).T
X, Y = np.meshgrid(x, y)
data[np.isinf(data)] = 10E3
data[np.isnan(data)] = 0
# print(X.T)
# X, Y = np.mgrid[0:1:100, 0:1:100]
print(Y.shape)
values = np.vstack([data[:,0],data[:,1]])
kde = stats.gaussian_kde(values)
# print((X,Y))
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)
Z=Z/Z.max() # normalization
# Out:
# (100, 100)

# %%
from functionFactory import *
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
# p=plt.matshow(Z, aspect=1, cmap=plt.get_cmap('seismic'))
plt.show()

p=plt.matshow(Z, aspect=1, cmap=plt.get_cmap('viridis'))
plt.colorbar(p)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="479.9999895962804">

# %%
# 1
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from fenics import *
from mshr import *
from ufl import nabla_grad, nabla_div, grad
from scipy.interpolate import interp2d
from abc import abstractmethod

# %matplotlib notebook

# %%
# 2
nu = 0.1
cDiff = 0.0027
dbar = 1.6925
cS = 0.5
N = 40*3 # Dimension of the grid
M = 100 # Dimension of the matrices
xmax = 1
tol = 1e-10

# %%
# 3
def fun(x, y, muX, muY, sigma):
    return gaussian2d(x, y, muX, muY, sigma, sigma)


def gaussian(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)


def gaussian2d(x, y, muX, muY, sigmaX, sigmaY):
    return 1 / (sigmaX * sigmaY * np.sqrt(2 * np.pi)) * np.exp(
        -0.5 * (((x - muX) / sigmaX) ** 2 + ((y - muY) / sigmaY) ** 2))

# N: dimension to, M: dimension from
def interpMat2(N, M, mat):
    xx = np.arange(0, 1.0, 1/(N+1))
    yy = np.arange(0, 1.0, 1/(N+1))
    x = np.arange(0, 1.0, 1/M)
    y = np.arange(0, 1.0, 1/M)
    f = interp2d(x,y,mat)
    mat = f(xx,yy)
    mat = mat.T
    mat = mat.reshape(np.prod(mat.shape))
    return mat

# r = Expression('1 + pow(2, x[0])', degree=2)
# a = Expression('0.5 * (1 - x[0]/xmax)', degree=2, xmax=xmax)
# c_k = Expression('x[0]*x[0]', degree=2)

# %%
# 4
x = np.arange(0, 1.0, 1 / M)
y = np.arange(0, 1.0, 1 / 100)
X, Y = np.meshgrid(x, y)

# %%
# 4
# %matplotlib notebook

zlog = -np.log(np.abs(Z))
zlog = zlog.reshape(X.shape)
plt.matshow(zlog, aspect=1, cmap=plt.get_cmap('jet'))
plt.matshow(zlog, aspect=1, cmap=plt.get_cmap('viridis'))
plt.title('Zlog projection')
plt.colorbar()
plt.axis('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.9999895962804">
# <img src="data:image/png;base64,..." width="479.9999895962804">

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.arange(0, 1.0, 1 / M)
y = np.arange(0, 1.0, 1 / M)
X, Y = np.meshgrid(x, y)
ui = np.array(fun(np.ravel(X), np.ravel(Y), 0.1, 0.8, 0.1))
ui = (ui-min(ui))/max(ui)
Ui = ui.reshape(X.shape)
# Z2 = z2.reshape(X.shape)
# ax.plot_surface(X, Y, Ui) 
# ax.plot_surface(X, Y, Z2, linewidth=1) 
ax.plot_wireframe(X, Y, Ui)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# 5
parameters['reorder_dofs_serial'] = False
mesh = UnitSquareMesh(N, N)  # 8X8 rectangles, each divided in 2 triangle, hence 128 cells, and 81 (9^2) vertices
Vhat = FunctionSpace(mesh, 'P', 1)  # P returns Lagrangian polynomials, 1 is the degree of the FE

# %%
from functionFactory import *
# from makeFunction import *

# %%
# 6
# %matplotlib notebook

factory = functionFactory(Vhat, N, M)
Z +=0.005
zs = Z.ravel()
zexp = np.exp(-((zs-min(zs))/-min(zs)))
uhmst = zexp.reshape(X.shape)
uhmst[uhmst<0.04]=1e-15
cDth = 1. / uhmst.T
cDth[cDth>=0.98] = 100
cDthFct = factory(cDth)
factory.plot(cDth, title='Death rate')

zlog = -np.log(np.abs(zs))
zlogFct = factory(zlog)
factory.plot(zlog,title='Homeostasis landscape')


# Very basic initial conditon
UiFct = factory(0.1*Ui.T)
factory.plot(Ui.T, title='initial conditions')

def rct(x_, y_):
    return -1 + 2**x_


cRctMat = np.array(rct(np.ravel(X), np.ravel(Y)))
cRctMat = cRctMat.reshape(X.shape)
cRctFct = factory(cRctMat.T)
# factory.plot(cRctMat.T,title='Reaction rate')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# 7
def R1(u_):
    uv = u_.vector().get_local()
    cDth = cDthFct.vector().get_local()
    cRct = cRctFct.vector().get_local()
    temp = (cDth * uv)
    temp[temp > dbar] = dbar
    temp = (1 - temp)*cRct
    return temp


def v1():
    return zlogFct


def boundary(x, on_boundary):
    return on_boundary


# Differtiation rate
# Needs to be 1d --> np-ravel
def a(x_,y_):
    return 0.5*(1 - x_/max(x_))

# PT/ direction of the differentiation
def c_k_x(x_, y_):
    return x_**2

def c_k_y(x_, y_):
    return 1-y_**2

# %%
# 6
cAdvMat = np.array(a(np.ravel(X), np.ravel(Y)))
cAdvMat = cAdvMat.reshape(X.shape)
cAdvFct = factory(cAdvMat.T)
factory.plot(cAdvMat.T, title='Advection rate')

# !! Y component in vector space
cAMat_x = np.array(c_k_x(np.ravel(X), np.ravel(Y)))
cAMat_x = cAMat_x.reshape(X.shape)
cAFct_x = factory(cAMat_x.T)
factory.plot(cAMat_x.T, title='Differentiation rate x')


cAMat_y = np.array(c_k_y(np.ravel(X), np.ravel(Y)))
cAMat_y = cAMat_y.reshape(Y.shape)
cAFct_y = factory(cAMat_y.T)
factory.plot(cAMat_y.T, title='Differentiation rate y')
factory.plot(cAMat.T*cAMat_y.T*cAMat_x, title='Differentiation rate')

def v2_x(u_):
#     cAdv = cDthFct.vector().get_local()
    cAdv = cAdvFct.vector().get_local()
    cA = cAFct_x.vector().get_local()
    cRct = cRctFct.vector().get_local()
    return cA*(1-cAdv)*cRct

def v2_y(u_):
#     cAdv = cDthFct.vector().get_local()
    cAdv = cAdvFct.vector().get_local()
    cA = cAFct_y.vector().get_local()
    cRct = cRctFct.vector().get_local()
    return cA*(1-cAdv)*cRct
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# 8
# %matplotlib notebook

zero = Constant(0)
bc = DirichletBC(Vhat, zero, boundary)

u = TrialFunction(Vhat)  # here it is just defined as an unknown to define a.
v = TestFunction(Vhat)
u_n = Function(Vhat)
R = Function(Vhat)
V2Fct_x = Function(Vhat) 
V2Fct_y = Function(Vhat) 

u_n = interpolate(UiFct, Vhat) # initial value

# plt.figure()
# p = plot(u_n)
# plt.colorbar(p)
# plt.show()

T = 20.0  # final time
num_step = 200
dt = T / num_step
k = 1./dt
tol = 1e-6

R.vector()[:] = R1(u_n)
V2Fct_x.vector()[:] = v2_x(u_n)
V2Fct_y.vector()[:] = v2_y(u_n)

F = dot((u-u_n)*k,v)*dx + nu * dot(grad(u), grad(v)) * dx + dot(nabla_grad(v1())*u, nabla_grad(v)) * dx - \
    dot( R*u, v) * dx - dot(V2Fct_x*u, v.dx(0))* dx - dot(V2Fct_y*u, v.dx(1))* dx
#F = dot((u-u_n)*k,v)*dx + nu * dot(grad(u), grad(v)) * dx + dot(nabla_grad(v1())*u, nabla_grad(v)) * dx - \
#    dot( R*u, v) * dx - dot(V2Fct*u, nabla_grad(v)) * dx
# - dot( v2(u), grad(v)) * dx
# - dot( R(u), v) * dx
# - dot( v2(u), grad(v)) * dx
# - dot( Adv(u), grad(v)) * dx
# dot(nabla_grad(zlogFct)*u, nabla_grad(v)) * dx

u = Function(Vhat)
a = lhs(F)
L = rhs(F)
t = 0

## uncomment to save the solution onto pvd files. Can be used to plot dynamically in paraview
# vtkfile = File('framework/solution.pvd')
# vtkfile << (u_n, t)

for n in range(num_step):
    R.vector()[:] = R1(u_n)
    V2Fct_x.vector()[:] = v2_x(u_n)
    V2Fct_y.vector()[:] = v2_y(u_n)
    t+=dt
    solve(a == L, u, bc)
    u_e = interpolate(u_n, Vhat)
    error = np.abs(u_e.vector().get_local() - u.vector().get_local()).max()
    print('t = %.2f: difference = %.3g' % (t, error)) #relative errror
#     if (error < tol):
#         break
#     print(max(u.vector()))
#     print(min(u.vector()))
#     vtkfile << (u, t)
#     plt.figure()
#     p = plot(u)
#     plt.colorbar(p)
#     plt.show()
    u_n.assign(u)
    
# print(u.vector().get_local().shape)
# print(max(u.vector()))
# print(min(u.vector()))

plt.figure()
p = plot(u)
plt.colorbar(p)
plt.show()
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# t = 0.10: difference = 1.53
# t = 0.20: difference = 0.107
# t = 0.30: difference = 0.0171
# t = 0.40: difference = 0.0146
# t = 0.50: difference = 0.0141
# t = 0.60: difference = 0.0141
# t = 0.70: difference = 0.0141
# t = 0.80: difference = 0.0142
# t = 0.90: difference = 0.0142
# t = 1.00: difference = 0.0143
# t = 1.10: difference = 0.0144
# t = 1.20: difference = 0.0144
# t = 1.30: difference = 0.0145
# t = 1.40: difference = 0.0146
# t = 1.50: difference = 0.0147
# t = 1.60: difference = 0.0148
# t = 1.70: difference = 0.0149
# t = 1.80: difference = 0.015
# t = 1.90: difference = 0.0151
# t = 2.00: difference = 0.0152
# t = 2.10: difference = 0.0153
# t = 2.20: difference = 0.0154
# t = 2.30: difference = 0.0155
# t = 2.40: difference = 0.0157
# t = 2.50: difference = 0.0158
# t = 2.60: difference = 0.0159
# t = 2.70: difference = 0.0161
# t = 2.80: difference = 0.0162
# t = 2.90: difference = 0.0164
# t = 3.00: difference = 0.0165
# t = 3.10: difference = 0.0167
# t = 3.20: difference = 0.0168
# t = 3.30: difference = 0.017
# t = 3.40: difference = 0.0172
# t = 3.50: difference = 0.0174
# t = 3.60: difference = 0.0175
# t = 3.70: difference = 0.0177
# t = 3.80: difference = 0.0179
# t = 3.90: difference = 0.0181
# t = 4.00: difference = 0.0183
# t = 4.10: difference = 0.0185
# t = 4.20: difference = 0.0188
# t = 4.30: difference = 0.0191
# t = 4.40: difference = 0.0197
# t = 4.50: difference = 0.0203
# t = 4.60: difference = 0.021
# t = 4.70: difference = 0.0216
# t = 4.80: difference = 0.0222
# t = 4.90: difference = 0.0229
# t = 5.00: difference = 0.0236
# t = 5.10: difference = 0.0243
# t = 5.20: difference = 0.0249
# t = 5.30: difference = 0.0256
# t = 5.40: difference = 0.0263
# t = 5.50: difference = 0.0271
# t = 5.60: difference = 0.0278
# t = 5.70: difference = 0.0285
# t = 5.80: difference = 0.0293
# t = 5.90: difference = 0.03
# t = 6.00: difference = 0.0308
# t = 6.10: difference = 0.0316
# t = 6.20: difference = 0.0324
# t = 6.30: difference = 0.0332
# t = 6.40: difference = 0.034
# t = 6.50: difference = 0.0349
# t = 6.60: difference = 0.0357
# t = 6.70: difference = 0.0366
# t = 6.80: difference = 0.0374
# t = 6.90: difference = 0.0383
# t = 7.00: difference = 0.0392
# t = 7.10: difference = 0.0402
# t = 7.20: difference = 0.0411
# t = 7.30: difference = 0.0421
# t = 7.40: difference = 0.043
# t = 7.50: difference = 0.044
# t = 7.60: difference = 0.045
# t = 7.70: difference = 0.046
# t = 7.80: difference = 0.0471
# t = 7.90: difference = 0.0482
# t = 8.00: difference = 0.0492
# t = 8.10: difference = 0.0503
# t = 8.20: difference = 0.0515
# t = 8.30: difference = 0.0526
# t = 8.40: difference = 0.0538
# t = 8.50: difference = 0.055
# t = 8.60: difference = 0.0562
# t = 8.70: difference = 0.0574
# t = 8.80: difference = 0.0587
# t = 8.90: difference = 0.06
# t = 9.00: difference = 0.0613
# t = 9.10: difference = 0.0626
# t = 9.20: difference = 0.064
# t = 9.30: difference = 0.0654
# t = 9.40: difference = 0.0668
# t = 9.50: difference = 0.0682
# t = 9.60: difference = 0.0697
# t = 9.70: difference = 0.0712
# t = 9.80: difference = 0.0728
# t = 9.90: difference = 0.0743
# t = 10.00: difference = 0.0759
# t = 10.10: difference = 0.0776
# t = 10.20: difference = 0.0793
# t = 10.30: difference = 0.081
# t = 10.40: difference = 0.0827
# t = 10.50: difference = 0.0845
# t = 10.60: difference = 0.0863
# t = 10.70: difference = 0.0882
# t = 10.80: difference = 0.0901
# t = 10.90: difference = 0.0921
# t = 11.00: difference = 0.0941
# t = 11.10: difference = 0.0961
# t = 11.20: difference = 0.0982
# t = 11.30: difference = 0.1
# t = 11.40: difference = 0.102
# t = 11.50: difference = 0.105
# t = 11.60: difference = 0.107
# t = 11.70: difference = 0.109
# t = 11.80: difference = 0.113
# t = 11.90: difference = 0.117
# t = 12.00: difference = 0.122
# t = 12.10: difference = 0.126
# t = 12.20: difference = 0.131
# t = 12.30: difference = 0.136
# t = 12.40: difference = 0.141
# t = 12.50: difference = 0.146
# t = 12.60: difference = 0.151
# t = 12.70: difference = 0.157
# t = 12.80: difference = 0.162
# t = 12.90: difference = 0.168
# t = 13.00: difference = 0.174
# t = 13.10: difference = 0.181
# t = 13.20: difference = 0.187
# t = 13.30: difference = 0.194
# t = 13.40: difference = 0.201
# t = 13.50: difference = 0.209
# t = 13.60: difference = 0.216
# t = 13.70: difference = 0.224
# t = 13.80: difference = 0.232
# t = 13.90: difference = 0.241
# t = 14.00: difference = 0.25
# t = 14.10: difference = 0.259
# t = 14.20: difference = 0.268
# t = 14.30: difference = 0.278
# t = 14.40: difference = 0.288
# t = 14.50: difference = 0.299
# t = 14.60: difference = 0.31
# t = 14.70: difference = 0.321
# t = 14.80: difference = 0.333
# t = 14.90: difference = 0.345
# t = 15.00: difference = 0.358
# t = 15.10: difference = 0.371
# t = 15.20: difference = 0.384
# t = 15.30: difference = 0.398
# t = 15.40: difference = 0.413
# t = 15.50: difference = 0.428
# t = 15.60: difference = 0.444
# t = 15.70: difference = 0.46
# t = 15.80: difference = 0.477
# t = 15.90: difference = 0.494
# t = 16.00: difference = 0.512
# t = 16.10: difference = 0.531
# t = 16.20: difference = 0.55
# t = 16.30: difference = 0.57
# t = 16.40: difference = 0.591
# t = 16.50: difference = 0.613
# t = 16.60: difference = 0.635
# t = 16.70: difference = 0.658
# t = 16.80: difference = 0.682
# t = 16.90: difference = 0.707
# t = 17.00: difference = 0.733
# t = 17.10: difference = 0.759
# t = 17.20: difference = 0.787
# t = 17.30: difference = 0.816
# t = 17.40: difference = 0.846
# t = 17.50: difference = 0.876
# t = 17.60: difference = 0.908
# t = 17.70: difference = 0.942
# t = 17.80: difference = 0.976
# t = 17.90: difference = 1.01
# t = 18.00: difference = 1.05
# t = 18.10: difference = 1.09
# t = 18.20: difference = 1.13
# t = 18.30: difference = 1.17
# t = 18.40: difference = 1.21
# t = 18.50: difference = 1.25
# t = 18.60: difference = 1.3
# t = 18.70: difference = 1.35
# t = 18.80: difference = 1.4
# t = 18.90: difference = 1.45
# t = 19.00: difference = 1.5
# t = 19.10: difference = 1.55
# t = 19.20: difference = 1.61
# t = 19.30: difference = 1.67
# t = 19.40: difference = 1.73
# t = 19.50: difference = 1.79
# t = 19.60: difference = 1.86
# t = 19.70: difference = 1.93
# t = 19.80: difference = 2
# t = 19.90: difference = 2.07
# t = 20.00: difference = 2.14
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
p=plt.matshow(u.vector()[:].reshape(121,121), aspect=1, cmap=plt.get_cmap('viridis'))
plt.colorbar(p)
# Out:
# <img src="data:image/png;base64,..." width="479.9999895962804">

# %%
ulog = interpolate(u, Vhat)
ulog.vector()[:] = np.log2(ulog.vector()[:]+0.2)
ulog.vector()[np.isnan(ulog.vector()[:]) ] = 0
ulog.vector()[np.isinf(ulog.vector()[:]) ] = 0
ulog = interpolate(ulog, Vhat)
plt.figure()
p = plot(ulog)
plt.colorbar(p)
plt.show()

p=plt.matshow(ulog.vector()[:].reshape(121,121), aspect=1, cmap=plt.get_cmap('viridis'))
plt.colorbar(p)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="479.9999895962804">

# %%
# 9
from matplotlib.widgets import RectangleSelector
def line_select_callback(eclick, erelease):
    'eclick and erelease are the press and release events'
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    print("(%3.2f, %3.2f) --> (%3.2f, %3.2f)" % (x1, y1, x2, y2))
    print(" The button you used were: %s %s" % (eclick.button, erelease.button))



fig, current_ax = plt.subplots()                 # make a new plotting range
# p = plot(UiFct)
p = plot(ulog)
plt.colorbar(p)
def toggle_selector(event):
    print(' Key pressed.')
    if event.key in ['Q', 'q'] and toggle_selector.RS.active:
        print(' RectangleSelector deactivated.')
        toggle_selector.RS.set_active(False)
    if event.key in ['A', 'a'] and not toggle_selector.RS.active:
        print(' RectangleSelector activated.')
        toggle_selector.RS.set_active(True)

print("\n      click  -->  release")

# drawtype is 'box' or 'line' or 'none'
toggle_selector.RS = RectangleSelector(current_ax, line_select_callback,
                                       drawtype='box', useblit=True,
                                       button=[1, 3],  # don't use middle button
                                       minspanx=5, minspany=5,
                                       spancoords='pixels',
                                       interactive=True)
plt.connect('key_press_event', toggle_selector)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
#       click  -->  release

# %%
# 9
# print(toggle_selector.RS.geometry)
x1, x2, y1 ,y2, z = toggle_selector.RS.geometry.T
# print(x1)
# print(x2)
# print(y1)
# print(y2)
p1 = Point(x1[1], x1[0])
p2 = Point(y1[1], y1[0])

NewMesh = RectangleMesh(p1,p2,N,N)
# plot(NewMesh)
VInt = FunctionSpace(NewMesh, "Lagrange", 2)
uInt = project(ulog, VInt)
print(assemble(uInt*dx))
# print(assemble(u*dx))
print(uInt.vector().get_local().max())
# print(assemble(uInt*ds))
# print(assemble(uInt*dx))
# Out:
# 0.03364899967886643
# 5.923406201985339
